# %%
topic = "example-1"

# %%
from kafka import KafkaProducer
import json
producer = KafkaProducer(bootstrap_servers='kafka:9092', value_serializer=lambda v: json.dumps(v).encode('utf-8'))
for idx in range(1):
    msg = {
          "idx": idx, 
      "message": f"the message no={idx}"
      }
    future = producer.send(topic=topic, value=msg)
    result = future.get(timeout=60)
    producer.flush() 
    print(idx, result)
# Out:
# 0 RecordMetadata(topic='example-1', partition=1, topic_partition=TopicPartition(topic='example-1', partition=1), offset=11, timestamp=1765809667478, checksum=None, serialized_key_size=-1, serialized_value_size=41, serialized_header_size=-1)

# %%
from kafka import KafkaConsumer
consumer = KafkaConsumer(
    [topic],
    client_id="client-1",
    bootstrap_servers='kafka:9092',
    auto_offset_reset='earliest',
    value_deserializer=lambda x: json.loads(x.decode('utf-8'))
)

# %%
for msg in consumer:
    print(msg)
    print(msg.value)
# Out:
# ConsumerRecord(topic='example-1', partition=1, leader_epoch=0, offset=8, timestamp=1765809665982, timestamp_type=0, key=None, value={'idx': 0, 'message': 'the message no=0'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=41, serialized_header_size=-1)
# {'idx': 0, 'message': 'the message no=0'}
# ConsumerRecord(topic='example-1', partition=1, leader_epoch=0, offset=9, timestamp=1765809666518, timestamp_type=0, key=None, value={'idx': 0, 'message': 'the message no=0'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=41, serialized_header_size=-1)
# {'idx': 0, 'message': 'the message no=0'}
# ConsumerRecord(topic='example-1', partition=1, leader_epoch=0, offset=10, timestamp=1765809667017, timestamp_type=0, key=None, value={'idx': 0, 'message': 'the message no=0'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=41, serialized_header_size=-1)
# {'idx': 0, 'message': 'the message no=0'}
# ConsumerRecord(topic='example-1', partition=1, leader_epoch=0, offset=11, timestamp=1765809667478, timestamp_type=0, key=None, value={'idx': 0, 'message': 'the message no=0'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=41, serialized_header_size=-1)
# {'idx': 0, 'message': 'the message no=0'}
# ConsumerRecord(topic='example-1', partition=2, leader_epoch=0, offset=12, timestamp=1765809665372, timestamp_type=0, key=None, value={'idx': 0, 'message': 'the message no=0'}, headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=41, serialized_header_size=-1)
# {'idx': 0, 'message': 'the message no=0'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 for msg in consumer:
#       2     print(msg)
#       3     print(msg.value)
#
# File /Projects/boilerplate-kafka/.venv/lib/python3.12/site-packages/kafka/consumer/group.py:1213, in KafkaConsumer.__next__(self)
#    1211     self._iterator = self._message_generator_v2()
#    1212 try:
# -> 1213     return next(self._iterator)
#    1214 except StopIteration:
#    1215     self._iterator = None
#
# File /Projects/boilerplate-kafka/.venv/lib/python3.12/site-packages/kafka/consumer/group.py:1185, in KafkaConsumer._message_generator_v2(self)
#    1183 def _message_generator_v2(self):
#    1184     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1185     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1186     for tp, records in six.iteritems(record_map):
#    1187         # Generators are stateful, and it is possible that the tp / records
#    1188         # here may become stale during iteration -- i.e., we seek to a
#    1189         # different offset, pause consumption, or lose assignment.
#    1190         for record in records:
#    1191             # is_fetchable(tp) should handle assignment changes and offset
#    1192             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1193             # outer function destroying the existing iterator/generator
#    1194             # via self._iterator = None
#
# File /Projects/boilerplate-kafka/.venv/lib/python3.12/site-packages/kafka/consumer/group.py:708, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     706 timer = Timer(timeout_ms)
#     707 while not self._closed:
# --> 708     records = self._poll_once(timer, max_records, update_offsets=update_offsets)
#     709     if records:
#     710         return records
#
# File /Projects/boilerplate-kafka/.venv/lib/python3.12/site-packages/kafka/consumer/group.py:757, in KafkaConsumer._poll_once(self, timer, max_records, update_offsets)
#     754     log.debug('poll: do not have all fetch positions...')
#     755     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
# --> 757 self._client.poll(timeout_ms=poll_timeout_ms)
#     758 # after the long poll, we should check whether the group needs to rebalance
#     759 # prior to returning data so that the group can stabilize faster
#     760 if self._coordinator.need_rejoin():
#
# File /Projects/boilerplate-kafka/.venv/lib/python3.12/site-packages/kafka/client_async.py:685, in KafkaClient.poll(self, timeout_ms, future)
#     678         timeout = min(
#     679             user_timeout_ms,
#     680             metadata_timeout_ms,
#     681             idle_connection_timeout_ms,
#     682             request_timeout_ms)
#     683         timeout = max(0, timeout)  # avoid negative timeouts
# --> 685     self._poll(timeout / 1000)
#     687 # called without the lock to avoid deadlock potential
#     688 # if handlers need to acquire locks
#     689 responses.extend(self._fire_pending_completed_requests())
#
# File /Projects/boilerplate-kafka/.venv/lib/python3.12/site-packages/kafka/client_async.py:728, in KafkaClient._poll(self, timeout)
#     725 self._register_send_sockets()
#     727 start_select = time.time()
# --> 728 ready = self._selector.select(timeout)
#     729 end_select = time.time()
#     730 if self._sensors:
#
# File /Projects/boilerplate-kafka/.python/cpython-3.12.12-linux-aarch64-gnu/lib/python3.12/selectors.py:468, in EpollSelector.select(self, timeout)
#     466 ready = []
#     467 try:
# --> 468     fd_event_list = self._selector.poll(timeout, max_ev)
#     469 except InterruptedError:
#     470     return ready
#
# KeyboardInterrupt:

# %%
msg.value
# Out:
# {'idx': 6, 'message': 'the message no=6'}
